# %%
import pandas as pd
import json

# %%
with open("BP_data/czechData.json", encoding="utf8") as f:
    docs = json.load(f)

with open("BP_data/topicData.json", encoding="utf8") as f:
    topics = json.load(f)

# %%
df_docs = pd.DataFrame(docs)
df_docs.head()
# Out:
#                                                 text      id  \
# 0  Příchod nové evropské měny o půlnoci na 1. led...      d1
# 1  Česká republika se sice zatím k jednotné evrop...  d14000
# 2  V době, kdy eurobankomaty už několik hodin vyd...      d2
# 3  Jak na Nový rok, tak po celý rok. Platí-li zná...      d3
# 4  V první vteřině roku 2002 se v havlíčkobrodské...  d14001
#
#                                                title                     date
# 0  \n304 miliony lidí ve 12 zemích si začalo vymě...  Jan 2, 2002 12:00:00 AM
# 1                                                     Jan 2, 2002 12:00:00 AM
# 2                                                     Jan 2, 2002 12:00:00 AM
# 3  \nDva na jednoho. Zeman a Klaus ve svém prvním...  Jan 2, 2002 12:00:00 AM
# 4                                                     Jan 2, 2002 12:00:00 AM

# %%
df_docs = df_docs.drop("date", axis=1)
df_docs.head()
# Out:
#                                                 text      id  \
# 0  Příchod nové evropské měny o půlnoci na 1. led...      d1
# 1  Česká republika se sice zatím k jednotné evrop...  d14000
# 2  V době, kdy eurobankomaty už několik hodin vyd...      d2
# 3  Jak na Nový rok, tak po celý rok. Platí-li zná...      d3
# 4  V první vteřině roku 2002 se v havlíčkobrodské...  d14001
#
#                                                title
# 0  \n304 miliony lidí ve 12 zemích si začalo vymě...
# 1
# 2
# 3  \nDva na jednoho. Zeman a Klaus ve svém prvním...
# 4

# %%
df_topics = pd.DataFrame(topics)
df_topics.head()
# Out:
#                                            narrative  \
# 0  Relevantní jsou jakékoliv dokumenty, které pos...
# 1  Máme zájem o využití energie z tzv. obnoviteln...
# 2  Relevantní dokumenty zmiňují název filmu, hry ...
# 3  Hledáme informace o bezpečnostních opatřeních,...
# 4  Relevantní dokumenty uvádějí některé či hlavní...
#
#                                          description  id  \
# 0  Najděte dokumenty o růstech cen po zavedení Eura.  q1
# 1  Hledáme informace o využití energie z obnovite...  q2
# 2  Najděte dokumenty, jež podávají informace o he...  q3
# 3  Summit NATO a přijatá bezpečnostní opatření v ...  q4
# 4                Jaké příčiny může mít astma u dětí?  q5
#
#                                 title lang
# 0                        Inflace Eura   cs
# 1                  Obnovitelné zdroje   cs
# 2                      Role policisty   cs
# 3  Summit NATO a bezpečností opatření   cs
# 4                     Astma u dětství   cs

# %%
print(df_topics['lang'].unique())
# Out:
# ['cs']

# %%
df_topics = df_topics.drop(['narrative', 'lang'], axis=1)

# %%
df_topics.head()
# Out:
#                                          description  id  \
# 0  Najděte dokumenty o růstech cen po zavedení Eura.  q1
# 1  Hledáme informace o využití energie z obnovite...  q2
# 2  Najděte dokumenty, jež podávají informace o he...  q3
# 3  Summit NATO a přijatá bezpečnostní opatření v ...  q4
# 4                Jaké příčiny může mít astma u dětí?  q5
#
#                                 title
# 0                        Inflace Eura
# 1                  Obnovitelné zdroje
# 2                      Role policisty
# 3  Summit NATO a bezpečností opatření
# 4                     Astma u dětství

# %%
with open("BP_data/stop_words_czech.json", encoding="utf8") as f:
    stop_words = json.load(f)

# %%
import re
from unidecode import unidecode

def clean_text(text):
    text=re.sub('\w*\d\w*','', text)
    text=re.sub('\n',' ',text)
    text = re.sub(r'^https?:\/\/.*[\r\n]*', '', text)
    text=re.sub('[^A-Za-z0-9]+ ', ' ', text)
    text=re.sub('"().,_', '',text)
    return text

def clean_df(df):
    for col in df.columns:
        if col == 'id':
            continue
        df[col] = df[col].str.lower()
        df[col] = df[col].apply(lambda x: unidecode(x, "utf-8"))
        df[col] = df[col].apply(lambda x: clean_text(x))

clean_df(df_docs)
clean_df(df_topics)

# %%
df_docs.to_csv('BP_data/docs_cleaned.csv')
df_topics.to_csv('BP_data/topics_cleaned.csv')

# %%
df_docs.head()
# Out:
#                                                 text      id  \
# 0  prichod nove evropske meny o pulnoci na leden ...      d1
# 1  ceska republika se sice zatim k jednotne evrop...  d14000
# 2  v dobe kdy eurobankomaty uz nekolik hodin vyda...      d2
# 3  jak na novy rok tak po cely rok plati-li zname...      d3
# 4  v prvni vterine roku se v havlickobrodske nemo...  d14001
#
#                                                title
# 0   miliony lidi ve zemich si zacalo vymenovat sv...
# 1
# 2
# 3   dva na jednoho zeman a klaus ve svem prvnim s...
# 4

# %%
df_topics.head()
# Out:
#                                          description  id  \
# 0  najdete dokumenty o rustech cen po zavedeni eura.  q1
# 1  hledame informace o vyuziti energie z obnovite...  q2
# 2  najdete dokumenty jez podavaji informace o her...  q3
# 3  summit nato a prijata bezpecnostni opatreni v ...  q4
# 4                jake priciny muze mit astma u deti?  q5
#
#                                 title
# 0                        inflace eura
# 1                  obnovitelne zdroje
# 2                      role policisty
# 3  summit nato a bezpecnosti opatreni
# 4                     astma u detstvi

# %%
df_topics = df_topics.rename(columns={'description':'text'})

# %%
df_topics.head()
# Out:
#                                                 text  id  \
# 0  najdete dokumenty o rustech cen po zavedeni eura.  q1
# 1  hledame informace o vyuziti energie z obnovite...  q2
# 2  najdete dokumenty jez podavaji informace o her...  q3
# 3  summit nato a prijata bezpecnostni opatreni v ...  q4
# 4                jake priciny muze mit astma u deti?  q5
#
#                                 title
# 0                        inflace eura
# 1                  obnovitelne zdroje
# 2                      role policisty
# 3  summit nato a bezpecnosti opatreni
# 4                     astma u detstvi

# %%
df_combined = df_docs.append(df_topics, ignore_index=True)
df_combined
# Out:
#                                                     text      id  \
# 0      prichod nove evropske meny o pulnoci na leden ...      d1
# 1      ceska republika se sice zatim k jednotne evrop...  d14000
# 2      v dobe kdy eurobankomaty uz nekolik hodin vyda...      d2
# 3      jak na novy rok tak po cely rok plati-li zname...      d3
# 4      v prvni vterine roku se v havlickobrodske nemo...  d14001
# ...                                                  ...     ...
# 81780  hledame informace o ztratach na kulturnim dedi...     q46
# 81781  najdete dokumenty ktere pojednavaji o politick...     q47
# 81782  najdete dokumenty o laureatech nobelovy ceny z...     q48
# 81783  ve kterych africkych zemich probiha obcanska v...     q49
# 81784  najdete dokumenty o neuspesnych pokusech o ate...     q50
#
#                                                    title
# 0       miliony lidi ve zemich si zacalo vymenovat sv...
# 1
# 2
# 3       dva na jednoho zeman a klaus ve svem prvnim s...
# 4
# ...                                                  ...
# 81780             zaplavy a ztraty na kulturnim dedictvi
# 81781                            pim fortuynova politika
# 81782                            novelovy ceny za chemii
# 81783                            obcanske valky v africe
# 81784                         neuspesne pokusy o atentat
#
# [81785 rows x 3 columns]

# %%
from gensim.models import Word2Vec
# Out:
# C:\Users\janku\AppData\Local\Programs\Python\Python38\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
text = [x for x in df_combined['text']]
title = [x for x in df_combined['title']]

for i in title:
    text.append(i)

len(text)
# Out:
# 163570

# %%
import numpy as np

data = []

for i in text:
    data.append(i.split())

# %%
model = Word2Vec(data, vector_size=300, min_count=2, window=5, sg=1, workers=4)

# %%
model.save('BP_data/w2vmodel.model')
print(len(model.wv.key_to_index))
# Out:
# 325801

# %%
# Function returning vector reperesentation of a document
def get_embedding_w2v(doc_tokens):
    embeddings = []
    if len(doc_tokens)<1:
        return np.zeros(300)
    else:
        for tok in doc_tokens:
            if tok in model.wv.key_to_index:
                embeddings.append(model.wv.word_vec(tok))
            else:
                embeddings.append(np.random.rand(300))
        # mean the vectors of individual words to get the vector of the document
        return np.mean(embeddings, axis=0)

# Getting Word2Vec Vectors for Testing Corpus and Queries
df_docs['vector'] = df_docs['text'].apply(lambda x :get_embedding_w2v(x.split()))
df_topics['vector'] = df_topics['text'].apply(lambda x :get_embedding_w2v(x.split()))
# Out:
# <ipython-input-23-9725f3cf8369>:9: DeprecationWarning: Call to deprecated `word_vec` (Use get_vector instead).
#   embeddings.append(model.wv.word_vec(tok))

# %%
df_docs.head()
# Out:
#                                                 text      id  \
# 0  prichod nove evropske meny o pulnoci na leden ...      d1
# 1  ceska republika se sice zatim k jednotne evrop...  d14000
# 2  v dobe kdy eurobankomaty uz nekolik hodin vyda...      d2
# 3  jak na novy rok tak po cely rok plati-li zname...      d3
# 4  v prvni vterine roku se v havlickobrodske nemo...  d14001
#
#                                                title  \
# 0   miliony lidi ve zemich si zacalo vymenovat sv...
# 1
# 2
# 3   dva na jednoho zeman a klaus ve svem prvnim s...
# 4
#
#                                               vector
# 0  [-0.06511202786886916, 0.1703164008817582, 0.0...
# 1  [-0.0253067878951639, 0.16174144702934332, 0.0...
# 2  [-0.01440328729315948, 0.10518538704182073, 0....
# 3  [-0.03898168788097193, 0.13833440503854924, 0....
# 4  [0.005426974545447479, 0.13925755345903337, 0....

# %%
df_docs.to_csv('BP_data/vectorized_data.csv')
